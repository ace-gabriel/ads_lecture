# %% [markdown]
# # NYU CUSP: Applied Data Science, Network Analysis module, session 1
# # Network visualization and basic analysis

# %%
#add necessary libraries
import networkx as nx #library supporting networks
import matplotlib.pyplot as plt #plotting
#make sure plots are embedded into the notebook
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# first let's explore the data structure for the network provided by networkx

# %%
#create an empty undirected network
G=nx.Graph()
#add a node
G.add_node(1)
#add several nodes
G.add_nodes_from([2,3,4])
#we can add not only numbers but also text (or any other python object) as a node 
G.add_node('A')
#now add an edge
G.add_edge(1,2)
#and a set of edges
G.add_edges_from([(1,3),(1,4),(3,4),('A',3),('A',4)])

# %%
#now let's see what we've done
print(G.nodes())
print(G.edges())
# Out:
# ['A', 1, 2, 3, 4]
# [('A', 3), ('A', 4), (1, 2), (1, 3), (1, 4), (3, 4)]

# %%
np.random.seed(2011) #fix the origin of random generator - see below why
#now let's visualize, which turns out to be fairly simple with networkx
nx.draw(G,with_labels=True)

# %% [markdown]
# note that the locations are selected by random - this is why we fixed random generator to make sure appearance is always the same. But what if we have the locations of the nodes we want the python to stick to?

# %%
#set up the location for our nodes
pos={1:(50,50),2:(25,50),3:(75,75),4:(75,25),'A':(100,50)}
#visualize for fixed node locations
nx.draw(G,pos=pos,with_labels=True)

# %% [markdown]
# But networkx does not only allow to store and visualize the networks. It can also perform a lot of useful computations for us, including some network properties. Let's do node degrees for example

# %%
dict(G.degree())
# Out:
# {1: 3, 2: 1, 3: 3, 4: 3, 'A': 2}

# %%
#let's now use node degrees as sizes of the nodes visualized
nx.draw(G,pos=pos,node_size=50*np.array(dict(G.degree()).values())**2,with_labels=True)

# %% [markdown]
# networkx can also handle directed networks as well

# %%
G2=nx.DiGraph() #create a directed graph
#add same edges as before; notice that when we add edges nodes are added automatically
G2.add_edges_from([(1,2),(1,3),(1,4),(3,4),(4,3),('A',3),('A',4)])

# %%
#visualize the network showing directions
nx.draw(G2,pos=pos,with_labels=True,arrows=True)

# %%
#calculate incoming and outgoing degrees
print(G2.in_degree())
print(G2.out_degree())
# Out:
# [('A', 0), (1, 0), (2, 1), (3, 3), (4, 3)]
# [('A', 2), (1, 3), (2, 0), (3, 1), (4, 1)]

# %% [markdown]
# we can also handle a weighted network

# %%
G3=nx.DiGraph() #create a directed graph
#add same edges as before but with weights
G3.add_weighted_edges_from([(1,2,2),(1,3,2),(1,4,2),(3,4,1),('A',3,3),('A',4,3)])
#we can also add separate edges in the following way
G3.add_edge('A',1,weight=5)

# %%
#we can access all the edges outgoing from a node 'A' like
print(G3['A'])
#a specific edge like
G3['A'][1]['weight']=3
G3['A'][1]['distance']=3
print(G3['A'][1])
#and modify its properties like
# Out:
# {1: {'weight': 5}, 3: {'weight': 3}, 4: {'weight': 3}}
# {'distance': 3, 'weight': 3}

# %%
G3.edges(data=False)
# Out:
# OutEdgeView([('A', 1), ('A', 3), ('A', 4), (1, 2), (1, 3), (1, 4), (3, 4)])

# %%
#now let's extract all the edge weights into a list (in the same order as edges go)
w=[d['weight'] for (u,v,d) in G3.edges(data=True)]
print(w)
# Out:
# [3, 3, 3, 2, 2, 2, 1]

# %%
#and visualize the network using edge weights for the edge thikness
nx.draw(G3,pos=pos,with_labels=True,arrows=True,width=3*w,node_size=500)

# %% [markdown]
# ### Excercise 1.
# Visualize the star-like network with 6 nodes located around the circle and one in the center, being connected with the other 6 (all links directed from the center to the outer nodes). Center node should be marked as "C", while others - 1,2,3,4,5,6.

# %% [markdown]
# ## Network of air connections
#
# Now we'll visualize a real-world network of the world airports with direct air connections. File citiesTable.csv is the table of airports together with their lat-long coordinates, while citiesToCities.csv contains the connection data

# %%
import numpy as np
import pandas as pd

# %%
cities = pd.read_csv( 'data/citiesTable.csv' , index_col=0 )
cities.head()
# Out:
#              country name most active airport  long. most active airport  \
# city name
# London     United Kingdom            Heathrow                     -0.103
# Chicago     United States  Chicago Ohare Intl                    -87.842
# Paris              France   Charles De Gaulle                      2.916
# Moscow             Russia          Domododevo                     38.510
# Shanghai            China              Pudong                    122.342
#
#            lat. most active airport  number of routes  \
# city name
# London                       51.795              1984
# Chicago                      42.631              1406
# Paris                        49.021              1254
# Moscow                       55.681              1179
# Shanghai                     31.238              1115
#
#            number incoming flights  number outcoming flights  \
# city name
# London                         993                       992
# Chicago                        705                       702
# Paris                          626                       629
# Moscow                         589                       591
# Shanghai                       560                       556
#
#            number incoming domestic flights  \
# city name
# London                                   57
# Chicago                                 526
# Paris                                    68
# Moscow                                  231
# Shanghai                                357
#
#            number outcoming domestic flights  \
# city name
# London                                    57
# Chicago                                  523
# Paris                                     68
# Moscow                                   231
# Shanghai                                 353
#
#            number incoming international flights  \
# city name
# London                                       936
# Chicago                                      179
# Paris                                        558
# Moscow                                       358
# Shanghai                                     203
#
#            number outcoming international flights  only domestic flights  \
# city name
# London                                        934                      0
# Chicago                                       178                      0
# Paris                                         560                      0
# Moscow                                        359                      0
# Shanghai                                      202                      0
#
#            average distance  max. distance
# city name
# London                 3228          11153
# Chicago                2328          12416
# Paris                  3367          11652
# Moscow                 2772          10054
# Shanghai               2235          12245

# %%
#create a network with city names as nodes
Flights=nx.Graph()
Flights.add_nodes_from(cities.index)

# %%
#create a dictionary of city locations
CityPos={c:(cities['long. most active airport'][c],cities['lat. most active airport'][c])
         for c in cities.index}

# %%
CityPos
# Out:
# {'Deauville': (0.257, 49.608000000000004),
#  'Yibin': (104.90700000000001, 29.333000000000002),
#  'Lianyungang': (119.416, 34.916),
#  'Castlegar': (-117.38799999999999, 49.493),
#  'BRISTOL': (-82.01299999999999, 36.792),
#  'Toledo': (-83.68, 41.978),
#  'Norman Wells': (-126.664, 65.469),
#  'Dammam': (50.32899999999999, 26.785),
#  'Paamiut': (-49.438, 62.653),
#  'Livingstone': (26.371, -17.703),
#  'Lanai': (-156.92, 21.309),
#  'Mitu': (-69.72399999999999, 1.422),
#  'Bar Harbor': (-67.936, 44.748999999999995),
#  'Niamey': (2.306, 13.802),
#  'Kittila': (25.410999999999998, 68.168),
#  'Edmonton': (-113.3, 53.516000000000005),
#  'Caen': (-0.084, 49.288000000000004),
#  'Ludhiaha': (76.587, 31.424),
#  'Eek': (-161.407, 60.356),
#  'Baia Mare': (23.783, 48.097),
#  'Las Palmas': (-13.343, 29.575),
#  'Reykjavik': (-21.901, 64.21600000000001),
#  'Bahia Blanca': (-61.61600000000001, -38.542),
#  'Emmonak': (-164.15200000000002, 63.31),
#  'Rio Grande': (-67.583, -53.63),
#  'Groningen': (6.965, 53.199),
#  'Wuzhou': (111.413, 23.761),
#  'Horta': (-28.526999999999997, 38.866),
#  'Brest': (-4.031000000000001, 48.746),
#  'Kagoshima': (131.19899999999998, 32.338),
#  'Townsville': (147.275, -18.755),
#  'Granada': (-3.6289999999999996, 37.314),
#  'Nhatrang': (109.32, 12.379000000000001),
#  'Quesnel': (-122.184, 53.043),
#  'Pensacola': (-86.645, 30.789),
#  'Maputo': (32.954, -25.869),
#  'Raipur': (82.23100000000001, 21.3),
#  'Lhasa': (91.51899999999999, 29.496),
#  'Masbate': (124.04799999999999, 12.615),
#  'Porto Alegre': (-50.62, -29.991),
#  'Muan': (126.637, 35.652),
#  'Rock Sound': (-75.63, 25.486),
#  'Roxana': (-83.19200000000001, 10.948),
#  'Rennell Island': (160.105, -11.224),
#  'Masset': (-131.542, 54.045),
#  'Kudat': (117.39299999999999, 7.537000000000001),
#  'Iron Mountain': (-87.525, 46.363),
#  'Gizo': (157.44, -7.497000000000001),
#  'San Pedro Sula': (-87.87299999999999, 15.754000000000001),
#  'Cicia': (-178.90400000000002, -17.573),
#  'Newquai': (-4.993, 50.733999999999995),
#  'Marshall': (-161.377, 62.441),
#  'Puerto Maldonado': (-68.715, -12.357000000000001),
#  'Wichita': (-97.056, 38.083),
#  'Oita': (132.22799999999998, 33.799),
#  'Melbourne': (145.405, -37.455999999999996),
#  'Kamuela': (-155.447, 20.002),
#  'Haiphong': (107.208, 21.365),
#  'Bilbao': (-2.852, 43.501000000000005),
#  'Kuantan': (103.348, 4.292),
#  'Turany': (17.157, 49.251999999999995),
#  'Mudgee': (150.018, -32.271),
#  'Dalian': (121.897, 39.609),
#  'Faleolo': (-171.34799999999998, -13.717),
#  'Doha': (51.941, 25.435),
#  'Papeete': (-149.35299999999998, -17.262),
#  'Tupelo': (-88.617, 34.446),
#  'Flores (flores Isl.)': (-30.553, 39.758),
#  'Long Akah': (115.305, 3.5),
#  'Treasure Cay': (-76.986, 27.241999999999997),
#  'Samara': (50.25, 53.833),
#  'Ivano-Frankivsk': (25.143, 49.473),
#  'Williamsport': (-76.869, 41.403),
#  'Kinshasa': (15.74, -3.977),
#  'Madras': (80.3, 13.657),
#  'Miles City': (-105.81, 46.713),
#  'Torino': (8.082, 45.333999999999996),
#  'Dundee': (-2.377, 56.754),
#  'Umea': (20.471, 64.319),
#  'Ziguinchor': (-15.802999999999999, 12.925999999999998),
#  'St.-denis': (55.85, -20.811999999999998),
#  'Columbia': (-91.7, 39.363),
#  'North Whale Pass': (-132.537, 56.193000000000005),
#  'King Salmon': (-156.416, 59.126999999999995),
#  'Lihue': (-158.899, 22.625999999999998),
#  'Santo Angelo': (-53.61600000000001, -27.803),
#  'Abadan': (48.38, 30.618000000000002),
#  'Turaif': (39.218, 32.154),
#  'Maroantsetra': (50.147, -15.062000000000001),
#  'Ballina Byron Bay': (153.937, -28.724),
#  'Manizales': (-75.108, 5.0489999999999995),
#  'Kalispell': (-113.76, 48.516999999999996),
#  'Changde': (112.066, 29.531),
#  'Chuuk': (152.405, 7.769),
#  'Barter Island': (-143.304, 70.223),
#  'Guadalajara': (-102.852, 20.869),
#  'Kone': (165.396, -20.423),
#  'Bermuda': (-64.465, 32.606),
#  'Split': (16.496, 43.898),
#  'Laredo': (-99.103, 27.906),
#  'Visalia': (-118.988, 36.531),
#  'Jos': (9.448, 10.066),
#  'Augsburg': (11.552, 48.708),
#  'Galcaio': (47.757, 7.301),
#  'Constanta': (28.813000000000002, 44.603),
#  'Williams Harbour': (-55.641999999999996, 52.943999999999996),
#  'Campos': (-40.836999999999996, -21.498),
#  'False Pass': (-163.018, 55.412),
#  'Omsk': (73.517, 55.611000000000004),
#  'Basco': (122.633, 20.752),
#  'Khabarovsk': (135.313, 48.88),
#  'Ukhta': (53.803999999999995, 63.567),
#  'Lucknow': (81.482, 27.267),
#  'Chapeco': (-52.428000000000004, -26.558000000000003),
#  'Manston': (1.5759999999999998, 51.57),
#  'Ondangwa': (16.587, -17.797),
#  'Noorvik': (-160.371, 67.362),
#  'Aizwal': (93.337, 24.244),
#  'Boulder City': (-114.19, 35.941),
#  'Peshawar': (71.857, 34.656),
#  'Ibadan': (4.63, 7.604),
#  'Baku': (50.077, 40.779),
#  'Rio De Janeiro': (-42.74, -22.682),
#  'North Bay': (-79.038, 46.606),
#  'Godthaab': (-51.464, 64.318),
#  'Amberley': (142.765, -10.919),
#  'Phaplu': (87.0, 27.861),
#  'Huntington': (-82.264, 38.611),
#  'Erie': (-79.628, 42.136),
#  'Pangnirtung': (-65.523, 66.241),
#  'Longview': (-94.52, 32.64),
#  'Adelaide': (138.884, -34.909),
#  'Sanford': (-80.73, 29.296),
#  'Ontario': (-117.336, 34.093),
#  'Thompson': (-97.774, 56.335),
#  ...}

# %%
#visualize all the world airport cities
plt.figure(figsize = (12,6))
nx.draw(Flights,pos=CityPos,with_labels=False,arrows=False,node_size=25)

# %%
#now read the links
links = pd.read_csv( 'data/citiesToCities.csv' , index_col=None )
links.head()
# Out:
#    departure city  long. departure (decimal)  lat. departure (decimal)  \
# 0       Sao Paulo                    -46.116                   -23.054
# 1  Rio De Janeiro                    -42.740                   -22.682
# 2         Beijing                    116.974                    40.133
# 3    Johannesburg                     28.410                   -25.566
# 4        Honolulu                   -157.871                    21.531
#
#   departure country    arrival city  long. departure (decimal).1  \
# 0            Brazil  Rio De Janeiro                      -42.740
# 1            Brazil       Sao Paulo                      -46.116
# 2             China        Shanghai                      122.342
# 3      South Africa       Cape Town                       19.002
# 4     United States           Tokyo                      140.643
#
#    lat. departure (decimal).1 arrival country  number of routes  distance
# 0                     -22.682          Brazil                18       348
# 1                     -23.054          Brazil                18       348
# 2                      31.238           China                18      1100
# 3                     -33.942    South Africa                16      1299
# 4                      36.274           Japan                16      6103

# %%
#create list of edges as tuples
EN=len(links.index)
edgelist=[(links['departure city'][j],links['arrival city'][j]) for j in range(EN)]
edgelist
# Out:
# [('Sao Paulo', 'Rio De Janeiro'),
#  ('Rio De Janeiro', 'Sao Paulo'),
#  ('Beijing', 'Shanghai'),
#  ('Johannesburg', 'Cape Town'),
#  ('Honolulu', 'Tokyo'),
#  ('Tokyo', 'Honolulu'),
#  ('Tokyo', 'Seoul'),
#  ('Seoul', 'Tokyo'),
#  ('Tokyo', 'Los Angeles'),
#  ('Los Angeles', 'Tokyo'),
#  ('Shanghai', 'Beijing'),
#  ('Hong Kong', 'Bangkok'),
#  ('Bangkok', 'Hong Kong'),
#  ('Taipei', 'Shanghai'),
#  ('Shanghai', 'Taipei'),
#  ('Cape Town', 'Johannesburg'),
#  ('Kigali', 'Entebbe'),
#  ('Shanghai', 'Hong Kong'),
#  ('Hong Kong', 'Shanghai'),
#  ('Muscat', 'Abu Dhabi'),
#  ('New York', 'London'),
#  ('Abu Dhabi', 'Muscat'),
#  ('Shenzhen', 'Shanghai'),
#  ('Shanghai', 'Shenzhen'),
#  ('Taipei', 'Tokyo'),
#  ('Tokyo', 'Taipei'),
#  ('Sao Paulo', 'Belo Horizonte'),
#  ('New York', 'Washington'),
#  ('Washington', 'New York'),
#  ('Qingdao', 'Shanghai'),
#  ('Shanghai', 'Qingdao'),
#  ('Shanghai', 'Chongqing'),
#  ('Chongqing', 'Shanghai'),
#  ('Singapore', 'Jakarta'),
#  ('Jakarta', 'Singapore'),
#  ('Sydney', 'Melbourne'),
#  ('Beijing', 'Tokyo'),
#  ('Tokyo', 'Beijing'),
#  ('London', 'Geneva'),
#  ('Geneva', 'London'),
#  ('Sao Paulo', 'Buenos Aires'),
#  ('Buenos Aires', 'Sao Paulo'),
#  ('Singapore', 'Tokyo'),
#  ('Tokyo', 'Singapore'),
#  ('Chicago', 'New York'),
#  ('New York', 'Chicago'),
#  ('Sao Paulo', 'Brasilia'),
#  ('Bahrain', 'Doha'),
#  ('London', 'Frankfurt'),
#  ("Xi'an", 'Shanghai'),
#  ('Shanghai', "Xi'an"),
#  ('Moscow', 'St. Petersburg'),
#  ('Shanghai', 'Chengdu'),
#  ('Chengdu', 'Shanghai'),
#  ('Quito', 'Guayaquil'),
#  ('Belo Horizonte', 'Sao Paulo'),
#  ('Brasilia', 'Sao Paulo'),
#  ('Tenerife', 'London'),
#  ('London', 'Tenerife'),
#  ('Seoul', 'Shanghai'),
#  ('Tokyo', 'Hong Kong'),
#  ('Hong Kong', 'Tokyo'),
#  ('Shanghai', 'Tokyo'),
#  ('Tokyo', 'Shanghai'),
#  ('London', 'Belfast'),
#  ('Belfast', 'London'),
#  ('Malaga', 'London'),
#  ('London', 'Stockholm'),
#  ('Stockholm', 'London'),
#  ('Auckland', 'Sydney'),
#  ('Madrid', 'London'),
#  ('London', 'Madrid'),
#  ('Moscow', 'Krasnodar'),
#  ('London', 'Edinburgh'),
#  ('London', 'Amsterdam'),
#  ('Krasnodar', 'Moscow'),
#  ('Edinburgh', 'London'),
#  ('Jakarta', 'Kuala Lumpur'),
#  ('Amsterdam', 'London'),
#  ('Kigali', 'Nairobi'),
#  ('Zurich', 'London'),
#  ('London', 'Zurich'),
#  ('Frankfurt', 'London'),
#  ('Chicago', 'Washington'),
#  ('Chicago', 'Paris'),
#  ('London', 'New York'),
#  ('Los Angeles', 'San Francisco'),
#  ('Los Angeles', 'New York'),
#  ('Doha', 'Bahrain'),
#  ('Paris', 'Chicago'),
#  ('Chicago', 'London'),
#  ('London', 'Chicago'),
#  ('London', 'Los Angeles'),
#  ('Los Angeles', 'London'),
#  ('Sanya', 'Shanghai'),
#  ('Shanghai', 'Kunming'),
#  ('Shanghai', 'Guangzhou'),
#  ('Shanghai', 'Sanya'),
#  ('Shanghai', 'Macau'),
#  ('Macau', 'Shanghai'),
#  ('Kunming', 'Shanghai'),
#  ('Guangzhou', 'Shanghai'),
#  ('Osaka', 'Tokyo'),
#  ('Tokyo', 'Osaka'),
#  ('Osaka', 'Seoul'),
#  ('Seoul', 'Bangkok'),
#  ('Seoul', 'Osaka'),
#  ('Bangkok', 'Seoul'),
#  ('St. Petersburg', 'Moscow'),
#  ('Singapore', 'Kuala Lumpur'),
#  ('Singapore', 'Hong Kong'),
#  ('Kuala Lumpur', 'Singapore'),
#  ('Hong Kong', 'Singapore'),
#  ('Shanghai', 'Seoul'),
#  ('Tokyo', 'Bangkok'),
#  ('Melbourne', 'Sydney'),
#  ('Bangkok', 'Tokyo'),
#  ('Guangzhou', 'Bangkok'),
#  ('Bangkok', 'Guangzhou'),
#  ('Tokyo', 'Sapporo'),
#  ('Sapporo', 'Tokyo'),
#  ('London', 'Aberdeen'),
#  ('London', 'Barcelona'),
#  ('London', 'Malaga'),
#  ('Barcelona', 'London'),
#  ('Aberdeen', 'London'),
#  ('Sydney', 'Auckland'),
#  ('Kuala Lumpur', 'Bangkok'),
#  ('Bangkok', 'Kuala Lumpur'),
#  ('London', 'Dublin'),
#  ('Kuala Lumpur', 'Jakarta'),
#  ('Rio De Janeiro', 'Belo Horizonte'),
#  ('Belo Horizonte', 'Rio De Janeiro'),
#  ('Bujumbura', 'Nairobi'),
#  ('Munich', 'London'),
#  ('London', 'Munich'),
#  ('Calgary', 'London'),
#  ('Sydney', 'Los Angeles'),
#  ('San Francisco', 'Los Angeles'),
#  ('Paris', 'Newark'),
#  ('Chicago', 'Los Angeles'),
#  ('Minneapolis', 'Chicago'),
#  ('London', 'Calgary'),
#  ('London', 'Newark'),
#  ('Los Angeles', 'Sydney'),
#  ('Las Vegas', 'Los Angeles'),
#  ('Honolulu', 'Los Angeles'),
#  ('Newark', 'Paris'),
#  ('Newark', 'London'),
#  ('Washington', 'Chicago'),
#  ('Curitiba', 'Sao Paulo'),
#  ('Auckland', 'Melbourne'),
#  ('San Francisco', 'London'),
#  ('London', 'San Francisco'),
#  ('Nanning', 'Shanghai'),
#  ('Delhi', 'Calcutta'),
#  ('Calcutta', 'Delhi'),
#  ('Urumqi', "Xi'an"),
#  ('Singapore', 'Bangkok'),
#  ('Bangkok', 'Singapore'),
#  ('Ouagadougou', 'Cotonou'),
#  ('Cotonou', 'Ouagadougou'),
#  ('Singapore', 'Denpasar'),
#  ('Denpasar', 'Singapore'),
#  ('Sao Paulo', 'Curitiba'),
#  ('London', 'Las Palmas'),
#  ('London', 'Alicante'),
#  ('Alicante', 'London'),
#  ('Las Palmas', 'London'),
#  ('Istanbul', 'Tehran'),
#  ('Tehran', 'Istanbul'),
#  ('Sao Paulo', 'Porto Alegre'),
#  ('Denver', 'Washington'),
#  ('Washington', 'Denver'),
#  ("Xi'an", 'Hangzhou'),
#  ('Beijing', 'Urumqi'),
#  ('Beijing', 'Seoul'),
#  ('Beijing', 'Guangzhou'),
#  ('Seoul', 'Beijing'),
#  ('Sharm El Sheikh', 'London'),
#  ('London', 'Sharm El Sheikh'),
#  ('Okinawa', 'Tokyo'),
#  ('Singapore', 'Brisbane'),
#  ('London', 'Manchester'),
#  ('London', 'Copenhagen'),
#  ('Copenhagen', 'London'),
#  ('Brisbane', 'Singapore'),
#  ('Washington', 'Boston'),
#  ('Boston', 'Washington'),
#  ('Portland', 'Chicago'),
#  ('San Francisco', 'Seoul'),
#  ('Seoul', 'San Francisco'),
#  ('Kuwait', 'Bahrain'),
#  ('Dublin', 'London'),
#  ('Bahrain', 'Kuwait'),
#  ('Vitoria', 'Rio De Janeiro'),
#  ('Montreal', 'Toronto'),
#  ('Toronto', 'Montreal'),
#  ('Tenerife', 'Gran Canaria'),
#  ('Palma de Mallorca', 'Barcelona'),
#  ('Gran Canaria', 'Tenerife'),
#  ('Barcelona', 'Palma de Mallorca'),
#  ('Toronto', 'London'),
#  ('Vancouver', 'London'),
#  ('St. Louis', 'Chicago'),
#  ('San Jose', 'Los Angeles'),
#  ('San Francisco', 'Seattle'),
#  ('San Francisco', 'Chicago'),
#  ('San Francisco', 'New York'),
#  ('Chicago', 'St. Louis'),
#  ('Chicago', 'Minneapolis'),
#  ('Chicago', 'Detroit'),
#  ('Chicago', 'Boston'),
#  ('Mexico City', 'Los Angeles'),
#  ('Melbourne', 'Auckland'),
#  ('London', 'Toronto'),
#  ('London', 'Vancouver'),
#  ('London', 'Boston'),
#  ('Los Angeles', 'San Jose'),
#  ('Los Angeles', 'Chicago'),
#  ('Los Angeles', 'Mexico City'),
#  ('Los Angeles', 'Honolulu'),
#  ('New York', 'San Francisco'),
#  ('New York', 'Los Angeles'),
#  ('Detroit', 'Chicago'),
#  ('Boston', 'Chicago'),
#  ('Boston', 'London'),
#  ('London', 'Larnaca'),
#  ('Larnaca', 'London'),
#  ('San Francisco', 'Hong Kong'),
#  ('London', 'Washington'),
#  ('Washington', 'London'),
#  ('Hong Kong', 'San Francisco'),
#  ('Douala', 'Bangui'),
#  ('Bangui', 'Douala'),
#  ('Xiamen', 'Shanghai'),
#  ('Tianjin', 'Shanghai'),
#  ('Shenyang', 'Shanghai'),
#  ('Shanghai', 'Tianjin'),
#  ('Shanghai', 'Changcha'),
#  ('Shanghai', 'Xiamen'),
#  ('Shanghai', 'Shenyang'),
#  ('Shanghai', 'Nanning'),
#  ('Guiyang', 'Shanghai'),
#  ('Ufa', 'Moscow'),
#  ('Moscow', 'Kiev'),
#  ('Kiev', 'Moscow'),
#  ('Seoul', 'Cheju'),
#  ('Cheju', 'Seoul'),
#  ('Delhi', 'Bombay'),
#  ('Delhi', 'Bangalore'),
#  ('Bombay', 'Delhi'),
#  ('Bombay', 'Ahmedabad'),
#  ('Bangalore', 'Delhi'),
#  ("Xi'an", 'Urumqi'),
#  ('Wuhan', 'Chongqing'),
#  ('Beijing', 'Chengdu'),
#  ('Kunming', 'Chengdu'),
#  ('Chengdu', 'Beijing'),
#  ('Chengdu', 'Kunming'),
#  ('Chongqing', 'Wuhan'),
#  ('Chongqing', 'Guangzhou'),
#  ('Guangzhou', 'Chongqing'),
#  ('Sapporo', 'Osaka'),
#  ('Dar Es Salaam', 'Nairobi'),
#  ('Sao Paulo', 'Salvador'),
#  ('Sao Paulo', 'Florianopolis'),
#  ('Cuiaba', 'Sao Paulo'),
#  ('Tenerife', 'Manchester'),
#  ('Manchester', 'Tenerife'),
#  ('London', 'Gran Canaria'),
#  ('Gran Canaria', 'London'),
#  ('Ho Chi Minh City', 'Bangkok'),
#  ('Bangkok', 'Ho Chi Minh City'),
#  ('Okinawa', 'Osaka'),
#  ('Osaka', 'Okinawa'),
#  ('Dubai', 'Muscat'),
#  ('Monrovia', 'Accra'),
#  ('Porto Alegre', 'Sao Paulo'),
#  ('Accra', 'Monrovia'),
#  ('Sydney', 'Christchurch'),
#  ('Christchurch', 'Sydney'),
#  ('Shanghai', 'Wuhan'),
#  ('Kahului', 'Kona'),
#  ('Washington', 'Charleston'),
#  ('Washington', 'Atlanta'),
#  ('Honolulu', 'Molokai'),
#  ('Atlanta', 'Washington'),
#  ('Xiamen', 'Beijing'),
#  ('Xiamen', 'Hefei'),
#  ('Urumqi', 'Beijing'),
#  ('Qingdao', 'Harbin'),
#  ('Shanghai', 'Nanchang'),
#  ('Beijing', 'Xiamen'),
#  ('Beijing', 'Lanzhou'),
#  ('Beijing', 'Hangzhou'),
#  ('Beijing', 'Dalian'),
#  ('Beijing', 'Changcha'),
#  ('Beijing', 'Changchun'),
#  ('Lanzhou', 'Beijing'),
#  ('Kunming', 'Hangzhou'),
#  ('Nanchang', 'Shanghai'),
#  ('Hong Kong', 'Hangzhou'),
#  ('Hangzhou', "Xi'an"),
#  ('Hangzhou', 'Beijing'),
#  ('Hangzhou', 'Hong Kong'),
#  ('Hangzhou', 'Guangzhou'),
#  ('Hefei', 'Xiamen'),
#  ('Dalian', 'Beijing'),
#  ('Changcha', 'Beijing'),
#  ('Changchun', 'Beijing'),
#  ('Guangzhou', 'Beijing'),
#  ('Guangzhou', 'Hangzhou'),
#  ('Busan', 'Seoul'),
#  ('Seoul', 'Busan'),
#  ('Haikou', 'Changcha'),
#  ('Changcha', 'Haikou'),
#  ('Malta', 'London'),
#  ('London', 'Malta'),
#  ('Kilimanjaro', 'Mombasa'),
#  ('Entebbe', 'Kigali'),
#  ('Tokyo', 'Okinawa'),
#  ('Sydney', 'Bangkok'),
#  ('Nice', 'London'),
#  ('Manchester', 'London'),
#  ('Lisbon', 'London'),
#  ('London', 'Lisbon'),
#  ('London', 'Dubai'),
#  ('London', 'Nice'),
#  ('London', 'Glasgow'),
#  ('London', 'Faro'),
#  ('Johannesburg', 'Durban'),
#  ('Glasgow', 'London'),
#  ('Faro', 'London'),
#  ('Dubai', 'London'),
#  ('Durban', 'Johannesburg'),
#  ('Bangkok', 'Sydney'),
#  ('Washington', 'Orlando'),
#  ('Tenerife', 'Madrid'),
#  ('Moscow', 'Khabarovsk'),
#  ('Madrid', 'Tenerife'),
#  ('Khabarovsk', 'Moscow'),
#  ('Rome', 'London'),
#  ('Portland', 'New York'),
#  ('Chicago', 'Portland'),
#  ('New York', 'Portland'),
#  ('Auckland', 'Brisbane'),
#  ('Madrid', 'Lisbon'),
#  ('Madrid', 'Amsterdam'),
#  ('Lisbon', 'Madrid'),
#  ('Sverdlovsk', 'Moscow'),
#  ('Moscow', 'Sverdlovsk'),
#  ('Moscow', 'Novosibirsk'),
#  ('Moscow', 'Omsk'),
#  ('Moscow', 'Krasnoyarsk'),
#  ('Novosibirsk', 'Moscow'),
#  ('Omsk', 'Moscow'),
#  ('Madrid', 'Paris'),
#  ('Krasnoyarsk', 'Moscow'),
#  ('New York', 'Frankfurt'),
#  ('Frankfurt', 'New York'),
#  ('Paris', 'Madrid'),
#  ('Sochi', 'Moscow'),
#  ('Rio De Janeiro', 'Porto Alegre'),
#  ('Montreal', 'Paris'),
#  ('Santiago', 'Buenos Aires'),
#  ('Luanda', 'Kinshasa'),
#  ('Kinshasa', 'Douala'),
#  ('Kinshasa', 'Brussels'),
#  ('Buenos Aires', 'Santiago'),
#  ('Douala', 'Kinshasa'),
#  ('Conakry', 'Banjul'),
#  ('Paris', 'Montreal'),
#  ('Brussels', 'Luanda'),
#  ('Brussels', 'Kigali'),
#  ('Banjul', 'Conakry'),
#  ('Barcelona', 'Ibiza'),
#  ('Abidjan', 'Lome'),
#  ('Berlin', 'London'),
#  ('Palma de Mallorca', 'Madrid'),
#  ('Paris', 'London'),
#  ('London', 'Berlin'),
#  ('London', 'Paris'),
#  ('Toronto', 'Chicago'),
#  ('Toronto', 'New York'),
#  ('Vancouver', 'Los Angeles'),
#  ('Montreal', 'New York'),
#  ('Taipei', 'Los Angeles'),
#  ('Salvador', 'Recife'),
#  ('Sacramento', 'Los Angeles'),
#  ('San Francisco', 'Tokyo'),
#  ('Seattle', 'San Francisco'),
#  ('Seattle', 'Los Angeles'),
#  ('Seattle', 'Denver'),
#  ('Santiago', 'Lima'),
#  ('San Diego', 'Chicago'),
#  ('Palm Springs', 'San Francisco'),
#  ('Chicago', 'Tampa'),
#  ('Chicago', 'San Francisco'),
#  ('Chicago', 'Seattle'),
#  ('Chicago', 'Orlando'),
#  ('Chicago', 'Fort Lauderdale'),
#  ('Chicago', 'Atlanta'),
#  ('Kahului', 'Los Angeles'),
#  ('Tokyo', 'New York'),
#  ('Miami', 'London'),
#  ('Orlando', 'Chicago'),
#  ('London', 'Montreal'),
#  ('London', 'Miami'),
#  ('London', 'Houston'),
#  ('London', 'Atlanta'),
#  ('Los Angeles', 'Vancouver'),
#  ('Los Angeles', 'Taipei'),
#  ('Los Angeles', 'Sacramento'),
#  ('Los Angeles', 'Seattle'),
#  ('Los Angeles', 'Kahului'),
#  ('Los Angeles', 'Las Vegas'),
#  ('Los Angeles', 'Kona'),
#  ('Los Angeles', 'Washington'),
#  ('Los Angeles', 'Guadalajara'),
#  ('Los Angeles', 'Dallas-fort Worth'),
#  ('Los Angeles', 'Denver'),
#  ('Los Angeles', 'Boston'),
#  ('Los Angeles', 'Auckland'),
#  ('Las Vegas', 'Chicago'),
#  ('New York', 'Toronto'),
#  ('New York', 'Montreal'),
#  ('New York', 'Tokyo'),
#  ('New York', 'Paris'),
#  ('Houston', 'London'),
#  ('Washington', 'Los Angeles'),
#  ('Tokyo', 'San Francisco'),
#  ('Guadalajara', 'Los Angeles'),
#  ('Frankfurt', 'Dallas-fort Worth'),
#  ('Dallas-fort Worth', 'Los Angeles'),
#  ('Dallas-fort Worth', 'Frankfurt'),
#  ('Denver', 'Seattle'),
#  ('Denver', 'Los Angeles'),
#  ('Boston', 'Los Angeles'),
#  ('Atlanta', 'Chicago'),
#  ('Atlanta', 'London'),
#  ('Port Hartcourt', 'Abuja'),
#  ('Abuja', 'Port Hartcourt'),
#  ('Shanghai', 'Guiyang'),
#  ('Shanghai', 'Guilin'),
#  ('Shanghai', 'Haikou'),
#  ('Guilin', 'Shanghai'),
#  ('Haikou', 'Shanghai'),
#  ('Changcha', 'Shanghai'),
#  ('Istanbul', 'Izmir'),
#  ('Izmir', 'Istanbul'),
#  ('Kunming', 'Changcha'),
#  ('Changcha', 'Kunming'),
#  ('Mineralnye Vody', 'Moscow'),
#  ('Moscow', 'Ufa'),
#  ('Tokyo', 'Fukuoka'),
#  ('Fukuoka', 'Tokyo'),
#  ('Kathmandu', 'Delhi'),
#  ('Jammu', 'Delhi'),
#  ('Guwahati', 'Delhi'),
#  ('Delhi', 'Kathmandu'),
#  ('Delhi', 'Jammu'),
#  ('Delhi', 'Guwahati'),
#  ('Bombay', 'Bangalore'),
#  ('Bangalore', 'Madras'),
#  ('Bangalore', 'Bombay'),
#  ('Ahmedabad', 'Bombay'),
#  ('Zanzibar', 'Dar Es Salaam'),
#  ('Nairobi', 'Dar Es Salaam'),
#  ('Moscow', 'Berlin'),
#  ('Berlin', 'Moscow'),
#  ('Jeddah', 'Dubai'),
#  ('Dubai', 'Jeddah'),
#  ("Xi'an", 'Lanzhou'),
#  ("Xi'an", 'Yinchuan'),
#  ('Urumqi', 'Kashi'),
#  ('Jinan', 'Dalian'),
#  ('Beijing', 'Chongqing'),
#  ('Lanzhou', "Xi'an"),
#  ('Kashi', 'Urumqi'),
#  ('Yinchuan', "Xi'an"),
#  ('Hangzhou', 'Chongqing'),
#  ('Chengdu', 'Changcha'),
#  ('Chengdu', 'Guangzhou'),
#  ('Changcha', 'Chengdu'),
#  ('Chongqing', 'Beijing'),
#  ('Chongqing', 'Hangzhou'),
#  ('Guangzhou', 'Chengdu'),
#  ('Taipei', 'Singapore'),
#  ('Singapore', 'Taipei'),
#  ('Singapore', 'Manila'),
#  ('Manila', 'Singapore'),
#  ('Guayaquil', 'Quito'),
#  ('Ouagadougou', 'Niamey'),
#  ('Niamey', 'Ouagadougou'),
#  ('Douala', 'Cotonou'),
#  ('Cotonou', 'Douala'),
#  ('Kazan', 'Moscow'),
#  ('Kaliningrad', 'Moscow'),
#  ('Moscow', 'Kazan'),
#  ('Osaka', 'Sapporo'),
#  ('Seoul', 'Fukuoka'),
#  ('Fukuoka', 'Seoul'),
#  ('Lisbon', 'Barcelona'),
#  ('Barcelona', 'Madrid'),
#  ('Barcelona', 'Lisbon'),
#  ('Kahului', 'Molokai'),
#  ('Molokai', 'Honolulu'),
#  ('Kona', 'Kahului'),
#  ('Salvador', 'Sao Paulo'),
#  ('Londrina', 'Sao Paulo'),
#  ('Goiania', 'Rio De Janeiro'),
#  ('Rio De Janeiro', 'Goiania'),
#  ('Rio De Janeiro', 'Curitiba'),
#  ('Rio De Janeiro', 'Brasilia'),
#  ('Florianopolis', 'Sao Paulo'),
#  ('Curitiba', 'Rio De Janeiro'),
#  ('Sao Paulo', 'Uberlandia'),
#  ('Sao Paulo', 'Londrina'),
#  ('Sao Paulo', 'Cuiaba'),
#  ('Brasilia', 'Rio De Janeiro'),
#  ('Vienna', 'Moscow'),
#  ('Moscow', 'Vienna'),
#  ('Santiago', 'Madrid'),
#  ('Manchester', 'Alicante'),
#  ('Barcelona', 'Tenerife'),
#  ('Alicante', 'Manchester'),
#  ('Kuwait', 'Dubai'),
#  ('Dubai', 'Kuwait'),
#  ('Colombo', 'Male'),
#  ('Phoenix', 'Minneapolis'),
#  ('Wellington', 'Sydney'),
#  ('Phuket', 'Bangkok'),
#  ('Chiang Mai', 'Bangkok'),
#  ('Bangkok', 'Chiang Mai'),
#  ('Moscow', 'Rostov'),
#  ('Wuhan', 'Shanghai'),
#  ('Urumqi', 'Shanghai'),
#  ('Shanghai', 'Urumqi'),
#  ('Shanghai', 'Zhengzhou'),
#  ('Zhengzhou', 'Shanghai'),
#  ('Salt Lake City', 'Denver'),
#  ('Chicago', 'Charleston'),
#  ('Chicago', 'Amsterdam'),
#  ('Minneapolis', 'Denver'),
#  ('Washington', 'Portland'),
#  ('Washington', 'Detroit'),
#  ('Freeport', 'Fort Lauderdale'),
#  ('Freetown', 'Banjul'),
#  ('Fort Lauderdale', 'Freeport'),
#  ('Detroit', 'Denver'),
#  ('Denver', 'Salt Lake City'),
#  ('Denver', 'Minneapolis'),
#  ('Denver', 'Detroit'),
#  ('Denver', 'Atlanta'),
#  ('Charleston', 'Chicago'),
#  ('Charleston', 'Washington'),
#  ('Banjul', 'Freetown'),
#  ('Amsterdam', 'Chicago'),
#  ('Accra', 'Lome'),
#  ('Houston', 'Denver'),
#  ('Houston', 'Washington'),
#  ('Washington', 'Houston'),
#  ('Surabaya', 'Singapore'),
#  ('Singapore', 'Surabaya'),
#  ('Los Angeles', 'Guatemala City'),
#  ('Guatemala City', 'Los Angeles'),
#  ('Brisbane', 'Auckland'),
#  ('Yantai', 'Shanghai'),
#  ('Xiamen', 'Shenzhen'),
#  ('Xiamen', 'Nanjing'),
#  ('Xiamen', 'Zhengzhou'),
#  ("Xi'an", 'Beijing'),
#  ("Xi'an", 'Nanjing'),
#  ("Xi'an", 'Nanchang'),
#  ("Xi'an", 'Changcha'),
#  ('Wuhan', 'Beijing'),
#  ('Wenzhou', 'Shanghai'),
#  ('Wenzhou', 'Guangzhou'),
#  ('Qingdao', 'Guangzhou'),
#  ('Shenzhen', 'Hangzhou'),
#  ('Sanya', 'Hangzhou'),
#  ('Sanya', 'Zhengzhou'),
#  ('Shanghai', 'Yantai'),
#  ('Shanghai', 'Huhhot'),
#  ('San Francisco', 'Denver'),
#  ('Shanghai', 'Wenzhou'),
#  ('Shanghai', 'Nagoya'),
#  ('Beijing', "Xi'an"),
#  ('Beijing', 'Wuhan'),
#  ('Beijing', 'Nanjing'),
#  ('Beijing', 'Yinchuan'),
#  ('Beijing', 'Harbin'),
#  ('Beijing', 'Hong Kong'),
#  ('Tokyo', 'Guangzhou'),
#  ('Nanjing', 'Xiamen'),
#  ('Nanjing', "Xi'an"),
#  ('Nanjing', 'Beijing'),
#  ('Nanjing', 'Haikou'),
#  ('Nanjing', 'Guangzhou'),
#  ('Nagoya', 'Shanghai'),
#  ('Nanchang', "Xi'an"),
#  ('Yinchuan', 'Beijing'),
#  ('Harbin', 'Qingdao'),
#  ('Harbin', 'Beijing'),
#  ('Harbin', 'Hangzhou'),
#  ('Harbin', 'Dalian'),
#  ('Hong Kong', 'Beijing'),
#  ('Hangzhou', 'Shenzhen'),
#  ('Hangzhou', 'Sanya'),
#  ('Hangzhou', 'Kunming'),
#  ('Hangzhou', 'Harbin'),
#  ('Huhhot', 'Shanghai'),
#  ('Haikou', 'Nanjing'),
#  ('Dalian', 'Harbin'),
#  ('Denver', 'San Francisco'),
#  ('Changcha', "Xi'an"),
#  ('Zhengzhou', 'Xiamen'),
#  ('Zhengzhou', 'Sanya'),
#  ('Guangzhou', 'Wenzhou'),
#  ('Guangzhou', 'Qingdao'),
#  ('Guangzhou', 'Tokyo'),
#  ('Guangzhou', 'Nanjing'),
#  ('Taipei', 'Seoul'),
#  ('Seoul', 'Taipei'),
#  ('Tianjin', 'Hangzhou'),
#  ('Sanya', 'Changcha'),
#  ('Nanjing', 'Changcha'),
#  ('Hangzhou', 'Tianjin'),
#  ('Hangzhou', 'Changcha'),
#  ('Changcha', 'Sanya'),
#  ('Changcha', 'Nanjing'),
#  ('Changcha', 'Hangzhou'),
#  ('Entebbe', 'Addis Ababa'),
#  ('Addis Ababa', 'Entebbe'),
#  ('Singapore', 'Melbourne'),
#  ('Singapore', 'Frankfurt'),
#  ('Melbourne', 'Singapore'),
#  ('London', 'Budapest'),
#  ('Frankfurt', 'Singapore'),
#  ('Durban', 'Cape Town'),
#  ('Cape Town', 'Durban'),
#  ('Budapest', 'London'),
#  ('San Francisco', 'Boston'),
#  ('Orlando', 'Washington'),
#  ('New York', 'Denver'),
#  ('Denver', 'New York'),
#  ('Denver', 'Boston'),
#  ('Boston', 'Denver'),
#  ('Vladivostok', 'Moscow'),
#  ('Tenerife', 'Barcelona'),
#  ('Moscow', 'Vladivostok'),
#  ('Milano', 'Rome'),
#  ('Madrid', 'Gran Canaria'),
#  ('Gran Canaria', 'Barcelona'),
#  ('Rome', 'Milano'),
#  ('Barcelona', 'Gran Canaria'),
#  ('Rio De Janeiro', 'Buenos Aires'),
#  ('Buenos Aires', 'Rio De Janeiro'),
#  ('Amsterdam', 'Madrid'),
#  ('Penang', 'Kuala Lumpur'),
#  ('Moscow', 'Samara'),
#  ('Moscow', 'Irkutsk'),
#  ('Moscow', 'Sochi'),
#  ('Lisbon', 'Paris'),
#  ('Milan', 'Paris'),
#  ('Irkutsk', 'Moscow'),
#  ('Houston', 'Paris'),
#  ('Washington', 'Paris'),
#  ('Rome', 'Paris'),
#  ('Paris', 'Lisbon'),
#  ('Paris', 'Milan'),
#  ('Paris', 'Houston'),
#  ('Paris', 'Washington'),
#  ('Paris', 'Rome'),
#  ('Paris', 'Barcelona'),
#  ('Barcelona', 'Paris'),
#  ('Campinas', 'Belo Horizonte'),
#  ('Salvador', 'Rio De Janeiro'),
#  ('Porto Alegre', 'Rio De Janeiro'),
#  ('Rio De Janeiro', 'Vitoria'),
#  ('Belo Horizonte', 'Campinas'),
#  ('Belo Horizonte', 'Porto Seguro'),
#  ('Porto Seguro', 'Sao Paulo'),
#  ('Vancouver', 'Calgary'),
#  ('Monrovia', 'Abidjan'),
#  ('Ouagadougou', 'Brussels'),
#  ('Nairobi', 'Brussels'),
#  ('Lome', 'Brussels'),
#  ('Jeddah', 'Riyadh'),
#  ('Ibiza', 'Barcelona'),
#  ('Entebbe', 'Brussels'),
#  ('Douala', 'Brussels'),
#  ('Brussels', 'Monrovia'),
#  ('Brussels', 'Ouagadougou'),
#  ('Brussels', 'Douala'),
#  ('Brussels', 'Bujumbura'),
#  ('Brussels', 'Banjul'),
#  ('Brussels', 'Abidjan'),
#  ('Banjul', 'Brussels'),
#  ('Abidjan', 'Brussels'),
#  ('Valencia', 'Palma de Mallorca'),
#  ('Vienna', 'Barcelona'),
#  ('Salzburg', 'London'),
#  ('London', 'Duesseldorf'),
#  ('Palma de Mallorca', 'Valencia'),
#  ('Munich', 'Istanbul'),
#  ('Madrid', 'Palma de Mallorca'),
#  ('London', 'Hamburg'),
#  ('London', 'Basel-Mulhouse-Freiburg'),
#  ('London', 'Salzburg'),
#  ('Hamburg', 'London'),
#  ('Frankfurt', 'Vienna'),
#  ('Duesseldorf', 'London'),
#  ('Basel-Mulhouse-Freiburg', 'London'),
#  ('Barcelona', 'Vienna'),
#  ('Montreal', 'London'),
#  ('Taipei', 'San Francisco'),
#  ('Tampa', 'Chicago'),
#  ('Santa Ana', 'Chicago'),
#  ('Salt Lake City', 'Chicago'),
#  ('Salt Lake City', 'Los Angeles'),
#  ('Springfield', 'Chicago'),
#  ('San Francisco', 'Taipei'),
#  ('San Francisco', 'Palm Springs'),
#  ('San Francisco', 'Portland'),
#  ('Seattle', 'Chicago'),
#  ('San Diego', 'Los Angeles'),
#  ('Fort Myers', 'Chicago'),
#  ('Raleigh-durham', 'New York'),
#  ('Phoenix', 'Portland'),
#  ('Phoenix', 'Los Angeles'),
#  ('Philadelphia', 'Chicago'),
#  ('Portland', 'San Francisco'),
#  ('Portland', 'Phoenix'),
#  ('Portland', 'Los Angeles'),
#  ('Chicago', 'Toronto'),
#  ('Chicago', 'Springfield'),
#  ('Chicago', 'San Antonio'),
#  ('Chicago', 'San Diego'),
#  ('Chicago', 'Fort Myers'),
#  ('Chicago', 'Tokyo'),
#  ('Chicago', 'Mexico City'),
#  ('Chicago', 'Las Vegas'),
#  ('Chicago', 'Houston'),
#  ('Chicago', 'Dallas-fort Worth'),
#  ('Chicago', 'Denver'),
#  ('Tokyo', 'Chicago'),
#  ('New Orleans', 'Chicago'),
#  ('Miami', 'Paris'),
#  ('Mexico City', 'Chicago'),
#  ('Orlando', 'London'),
#  ('Orlando', 'Los Angeles'),
#  ('Orlando', 'New York'),
#  ('Madrid', 'New York'),
#  ('Lima', 'Santiago'),
#  ('Lihue', 'Los Angeles'),
#  ('London', 'Orlando'),
#  ('New York', 'Charlotte'),
#  ('London', 'Shannon'),
#  ('Los Angeles', 'San Diego'),
#  ('Los Angeles', 'Phoenix'),
#  ('Los Angeles', 'Orlando'),
#  ('Los Angeles', 'Lihue'),
#  ('Los Angeles', 'Albuquerque'),
#  ('Kona', 'Los Angeles'),
#  ('New York', 'Raleigh-durham'),
#  ('New York', 'Orlando'),
#  ('New York', 'Madrid'),
#  ('New York', 'Fort Lauderdale'),
#  ('New York', 'Boston'),
#  ('Houston', 'Chicago'),
#  ('Fort Lauderdale', 'Chicago'),
#  ('Fort Lauderdale', 'New York'),
#  ('Dallas-fort Worth', 'San Francisco'),
#  ('Dallas-fort Worth', 'Denver'),
#  ('Denver', 'Chicago'),
#  ('Denver', 'Dallas-fort Worth'),
#  ('Charlotte', 'New York'),
#  ('Paris', 'Miami'),
#  ('Paris', 'New York'),
#  ('Boston', 'New York'),
#  ('Auckland', 'Los Angeles'),
#  ('Chicago', 'Hong Kong'),
#  ('London', 'Delhi'),
#  ('London', 'Bombay'),
#  ('New York', 'Brussels'),
#  ('Hong Kong', 'Chicago'),
#  ('Delhi', 'London'),
#  ('Brussels', 'New York'),
#  ('Bombay', 'London'),
#  ('Porlamar', 'Caracas'),
#  ('Caracas', 'Porlamar'),
#  ('Zhuhai', 'Shanghai'),
#  ('Shijiazhuang', 'Shanghai'),
#  ('Shenyang', 'Hangzhou'),
#  ('Shanghai', 'Shijiazhuang'),
#  ('Shanghai', 'Fuzhou'),
#  ('Shanghai', 'Zhuhai'),
#  ('Hangzhou', 'Shenyang'),
#  ('Fuzhou', 'Shanghai'),
#  ('Shenyang', 'Zhengzhou'),
#  ('Kunming', 'Jinghong'),
#  ('Jinghong', 'Kunming'),
#  ('Zhengzhou', 'Shenyang'),
#  ('Moscow', 'Mineralnye Vody'),
#  ('Nagoya', 'Seoul'),
#  ('Seoul', 'Hong Kong'),
#  ('Hong Kong', 'Seoul'),
#  ('Seoul', 'Nagoya'),
#  ('Srinagar', 'Jammu'),
#  ('Srinagar', 'Delhi'),
#  ('Singapore', 'Bombay'),
#  ('Pune', 'Delhi'),
#  ('Patina', 'Delhi'),
#  ('Madras', 'Delhi'),
#  ('Madras', 'Bangalore'),
#  ('Lucknow', 'Delhi'),
#  ('Jammu', 'Srinagar'),
#  ('Hyderabad', 'Delhi'),
#  ('Hyderabad', 'Bombay'),
#  ('Goa', 'Bombay'),
#  ('Delhi', 'Srinagar'),
#  ('Delhi', 'Pune'),
#  ('Delhi', 'Madras'),
#  ('Delhi', 'Lucknow'),
#  ('Delhi', 'Hyderabad'),
#  ('Delhi', 'Bangkok'),
#  ('Delhi', 'Ahmedabad'),
#  ('Kochi', 'Bombay'),
#  ('Bombay', 'Singapore'),
#  ('Bombay', 'Hyderabad'),
#  ('Bombay', 'Goa'),
#  ('Bombay', 'Kochi'),
#  ('Bombay', 'Bangkok'),
#  ('Bangkok', 'Delhi'),
#  ('Bangkok', 'Bombay'),
#  ('Ahmedabad', 'Delhi'),
#  ('Montevideo', 'Buenos Aires'),
#  ('Buenos Aires', 'Montevideo'),
#  ('Vladivostok', 'Khabarovsk'),
#  ('Khabarovsk', 'Vladivostok'),
#  ('Trinidad', 'Santa Cruz'),
#  ('Seoul', 'Cebu'),
#  ('Cebu', 'Seoul'),
#  ('Nairobi', 'Mombasa'),
#  ('Dar Es Salaam', 'Zanzibar'),
#  ('Nicoya', 'San Jose'),
#  ('San Jose', 'Nicoya'),
#  ('Xining', "Xi'an"),
#  ('Xiamen', 'Kunming'),
#  ('Xiamen', 'Changcha'),
#  ("Xi'an", 'Xining'),
#  ("Xi'an", 'Chengdu'),
#  ("Xi'an", 'Chongqing'),
#  ('Wuhan', 'Nanning'),
#  ('Wuhan', 'Chengdu'),
#  ('Urumqi', 'Chengdu'),
#  ('Urumqi', 'Chongqing'),
#  ('Jinan', 'Harbin'),
#  ('Jinan', 'Chengdu'),
#  ('Shenzhen', 'Chengdu'),
#  ('Sanya', 'Chengdu'),
#  ('Nanning', 'Wuhan'),
#  ('Nanjing', 'Chongqing'),
#  ('Lhasa', 'Chongqing'),
#  ('Guiyang', 'Kunming'),
#  ('Kunming', 'Xiamen'),
#  ('Kunming', 'Guiyang'),
#  ('Kunming', 'Chongqing'),
#  ('Harbin', 'Jinan'),
#  ('Hong Kong', 'Chengdu'),
#  ('Dalian', 'Jinan'),
#  ('Chengdu', "Xi'an"),
#  ('Chengdu', 'Wuhan'),
#  ('Chengdu', 'Urumqi'),
#  ('Chengdu', 'Jinan'),
#  ('Chengdu', 'Shenzhen'),
#  ('Chengdu', 'Sanya'),
#  ('Chengdu', 'Hong Kong'),
#  ('Changcha', 'Xiamen'),
#  ('Changcha', 'Chongqing'),
#  ('Chongqing', "Xi'an"),
#  ('Chongqing', 'Urumqi'),
#  ('Chongqing', 'Nanjing'),
#  ('Chongqing', 'Lhasa'),
#  ('Chongqing', 'Kunming'),
#  ('Chongqing', 'Changcha'),
#  ('Taipei', 'Osaka'),
#  ('Singapore', 'Ho Chi Minh City'),
#  ('Singapore', 'Perth'),
#  ('Singapore', 'Penang'),
#  ('Ho Chi Minh City', 'Singapore'),
#  ('Perth', 'Singapore'),
#  ('Penang', 'Singapore'),
#  ('Osaka', 'Taipei'),
#  ('Moscow', 'Kaliningrad'),
#  ('Moscow', 'Chelyabinsk'),
#  ('Chelyabinsk', 'Moscow'),
#  ('Sharm El Sheikh', 'Manchester'),
#  ('Manchester', 'Sharm El Sheikh'),
#  ('Moscow', 'Odessa'),
#  ('Odessa', 'Moscow'),
#  ('Paris', 'Porto'),
#  ('Porto', 'Paris'),
#  ('San Jose', 'Phoenix'),
#  ('Phoenix', 'San Jose'),
#  ('Khartoum', 'Jeddah'),
#  ('Jeddah', 'Khartoum'),
#  ('Osh', 'Moscow'),
#  ('Moscow', 'Osh'),
#  ('Douala', 'Libreville'),
#  ('Milano', 'Barcelona'),
#  ('Madrid', 'Moscow'),
#  ('Madrid', 'Barcelona'),
#  ('Moscow', 'Madrid'),
#  ('Moscow', 'Barcelona'),
#  ('Barcelona', 'Milano'),
#  ('Barcelona', 'Moscow'),
#  ('Khabarovsk', 'Magadan'),
#  ('Magadan', 'Khabarovsk'),
#  ('Barcelona', 'Amsterdam'),
#  ('Amsterdam', 'Barcelona'),
#  ('Molokai', 'Kahului'),
#  ('Lanai', 'Honolulu'),
#  ('Honolulu', 'Kahului'),
#  ('Salvador', 'Brasilia'),
#  ('Salvador', 'Aracaju'),
#  ('Sao Luis', 'Belem'),
#  ('Porto Velho', 'Cuiaba'),
#  ('Goiania', 'Cuiaba'),
#  ('Florianopolis', 'Porto Alegre'),
#  ('Campo Grande', 'Sao Paulo'),
#  ('Sao Paulo', 'Campo Grande'),
#  ('Cuiaba', 'Goiania'),
#  ('Brasilia', 'Salvador'),
#  ('Belem', 'Sao Luis'),
#  ('Belem', 'Maraba'),
#  ('Aracaju', 'Salvador'),
#  ('Tenerife', 'East Midlands'),
#  ('Sevilla', 'Barcelona'),
#  ('London', 'Grenoble'),
#  ('Santiago', 'Barcelona'),
#  ('Porto', 'Madrid'),
#  ('Madrid', 'Porto'),
#  ('London', 'Fuerteventura'),
#  ('Grenoble', 'London'),
#  ('Fuerteventura', 'London'),
#  ('East Midlands', 'Tenerife'),
#  ('Barcelona', 'Sevilla'),
#  ('Barcelona', 'Santiago'),
#  ('Barcelona', 'Malaga'),
#  ('Malaga', 'Manchester'),
#  ('Malaga', 'Barcelona'),
#  ('Taiyuan', 'Shanghai'),
#  ('Shanghai', 'Taiyuan'),
#  ('Shanghai', 'Bangkok'),
#  ('Bangkok', 'Shanghai'),
#  ('Ko Samui', 'Singapore'),
#  ('Singapore', 'Ko Samui'),
#  ('Hanoi', 'Bangkok'),
#  ('Bangkok', 'Hanoi'),
#  ('Amman', 'Abu Dhabi'),
#  ('Milano', 'Brussels'),
#  ('Brussels', 'Milano'),
#  ('Male', 'Colombo'),
#  ('Muscat', 'Dubai'),
#  ('Karachi', 'Dubai'),
#  ('Dubai', 'Karachi'),
#  ('Jeddah', 'Alexandria'),
#  ('Alexandria', 'Jeddah'),
#  ('Seattle', 'Seoul'),
#  ('Porto Alegre', 'Montevideo'),
#  ('Navegantes', 'Sao Paulo'),
#  ('Minneapolis', 'Phoenix'),
#  ('Los Angeles', 'Seoul'),
#  ('New York', 'Seoul'),
#  ('Seoul', 'Seattle'),
#  ('Seoul', 'Los Angeles'),
#  ('Seoul', 'New York'),
#  ('Goiania', 'Sao Paulo'),
#  ('Brasilia', 'Goiania'),
#  ('Atlanta', 'Denver'),
#  ('Wellington', 'Auckland'),
#  ('Sydney', 'Wellington'),
#  ('Perth', 'Denpasar'),
#  ('Melbourne', 'Wellington'),
#  ('Melbourne', 'Brisbane'),
#  ('Denpasar', 'Perth'),
#  ('Brisbane', 'Melbourne'),
#  ('Dubai', 'Colombo'),
#  ('Colombo', 'Dubai'),
#  ('Chiang Rai', 'Bangkok'),
#  ('Bangkok', 'Phuket'),
#  ('Bangkok', 'Chiang Rai'),
#  ('Rostov', 'Moscow'),
#  ('Xiamen', 'Guangzhou'),
#  ("Xi'an", 'Wuhan'),
#  ('Wuhan', "Xi'an"),
#  ('Wuhan', 'Sanya'),
#  ...]

# %%
#add edges to the network
Flights.add_edges_from(edgelist)

# %%
#visualize the network
plt.figure(figsize = (12,6))
nx.draw(Flights,pos=CityPos,with_labels=False,node_size=15,style='dotted',edge_color='green')

# %%
#most connected airport
AirportDeg=dict(Flights.degree())
TopAirport=AirportDeg.keys()[np.argmax(AirportDeg.values())]
print('Most connected airport is {0} with {1} connections'.format(TopAirport,AirportDeg[TopAirport]))
# Out:
# Most connected airport is London with 311 connections

# %%
#least connected airport
LeastAirport=AirportDeg.keys()[np.argmin(AirportDeg.values())]
print('Most connected airport is {0} with {1} connections'.format(LeastAirport,AirportDeg[LeastAirport]))
# Out:
# Most connected airport is Bar Harbor with 1 connections

# %%
#compute network average number of connections per airport and network density
k_avg=mean(AirportDeg.values())
dens=k_avg/(len(Flights)-1)
print('Average number of connections per airport is {0}; network density ={1}'.format(k_avg,dens))
# Out:
# Average number of connections per airport is 10.4738955823; network density =0.00350649333188

# %% [markdown]
# ### Excercise 2.
# Create a list of top 20 most connected airports accross the world and visualize them among the rest using a larger size and different color for the top ones. Consider adding labels for the top airports
#
# Hint: Feel free to use width=0 to eliminate edges on the plot. You may plot the entire graph first and then a subgraph (use .subgraph([list of nodes])) of top airports on top; alternatively can use list of sizes and colors but top nodes might be overlayed with others that way; use node_size and node_color to set up size and color of the nodes in draw().
